# %% [markdown]
# ## Harvard CS50 Python Notes

# %%
print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)

# %% [markdown]
# __*objects:__ Print function can take any number of objects.
# **sep = ' ':** When you pass arguments through print, will be separated by a space
# **end = '\n':** Starts a new line - can replace with however you want to end the line

# %%
name = input("What is your name?")
print("Hello, ", end = "")
print(name)
#Can now put this on the end line.
# Out:
# Hello, Josh

# %%
# escaping
print("hello, \"friend\"")
# Out:
# hello, "friend"
